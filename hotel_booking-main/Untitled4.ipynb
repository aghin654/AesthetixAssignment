# %%
import pandas as pd

# %%
df_pokemon=pd.read_csv("/content/Pokemon.csv")

# %%
df_pokemon.head(5)
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df_pokemon.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# ...

# %%
df_fire=df_pokemon[df_pokemon['Type 1']=='Fire']
df_fire.head()
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 4       60       50     65           1      False
# 5       80       65     80           1      False
# 6      109       85    100           1      False
# 7      130       85    100           1      False
# 8      159      115    100           1      False

# %%
df_fire_sorted=df_fire.sort_values(by= 'Speed', ascending=False)
df_fire_sorted.head()
# Out:
#        #        Name Type 1    Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 731  663  Talonflame   Fire    Flying    499  78      81       71       74
# 437  392   Infernape   Fire  Fighting    534  76     104       71      104
# 736  668      Pyroar   Fire    Normal    507  86      68       72      109
# 84    78    Rapidash   Fire       NaN    500  65     100       70       80
# 723  655     Delphox   Fire   Psychic    534  75      69       72      114
#
#      Sp. Def  Speed  Generation  Legendary
# 731       69    126           6      False
# 437       71    108           4      False
# 736       66    106           6      False
# 84        80    105           1      False
# 723      100    104           6      False

# %%
df_pokemon.isnull().sum()
# Out:
# #               0
# Name            0
# Type 1          0
# Type 2        386
# Total           0
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
df_pokemon.plot(kind= 'scatter', x ='Attack',y='Defense')
plt.show()

# %%
counts=df_pokemon['Type 1'].value_counts()
counts.plot(kind='bar')
df_pokemon.xlabel('Type 1')
df_pokemon.ylabel('Type 1')
plot.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-66-1a8fd82a6512> in <cell line: 3>()
#       1 counts=df_pokemon['Type 1'].value_counts()
#       2 counts.plot(kind='bar')
# ----> 3 df_pokemon.xlabel('Type 1')
#       4 df_pokemon.ylabel('Type 1')
#       5 plot.show()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'xlabel'

# %% [markdown]
# EMPLOYEE DETAILS

# %%
import pandas as pd

# %%
df_Employee=pd.read_csv('/content/Employee.csv')

# %%
df_Employee.head(5)
# Out:
#    Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0  Bachelors         2017  Bangalore            3   34    Male          No
# 1  Bachelors         2013       Pune            1   28  Female          No
# 2  Bachelors         2014  New Delhi            3   38  Female          No
# 3    Masters         2016  Bangalore            3   27    Male          No
# 4    Masters         2017       Pune            3   24    Male         Yes
#
#    ExperienceInCurrentDomain  LeaveOrNot
# 0                          0           0
# 1                          3           1
# 2                          2           0
# 3                          5           1
# 4                          2           1

# %%
df_Employee.describe()
# Out:
#        JoiningYear  PaymentTier          Age  ExperienceInCurrentDomain  \
# count  4653.000000  4653.000000  4653.000000                4653.000000
# mean   2015.062970     2.698259    29.393295                   2.905652
# std       1.863377     0.561435     4.826087                   1.558240
# min    2012.000000     1.000000    22.000000                   0.000000
# 25%    2013.000000     3.000000    26.000000                   2.000000
# 50%    2015.000000     3.000000    28.000000                   3.000000
# 75%    2017.000000     3.000000    32.000000                   4.000000
# max    2018.000000     3.000000    41.000000                   7.000000
#
#         LeaveOrNot
# count  4653.000000
# mean      0.343864
# std       0.475047
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000

# %%
df_Employee=df_Employee[df_Employee['City']=='Bangalore']
df_Employee.head()
# Out:
#     Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0   Bachelors         2017  Bangalore            3   34    Male          No
# 3     Masters         2016  Bangalore            3   27    Male          No
# 5   Bachelors         2016  Bangalore            3   22    Male          No
# 7   Bachelors         2016  Bangalore            3   34  Female          No
# 10    Masters         2012  Bangalore            3   27    Male          No
#
#     ExperienceInCurrentDomain  LeaveOrNot
# 0                           0           0
# 3                           5           1
# 5                           0           0
# 7                           2           1
# 10                          5           1

# %%
df=df_Employee.groupby('City')
df.head()
# Out:
#     Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0   Bachelors         2017  Bangalore            3   34    Male          No
# 1   Bachelors         2013       Pune            1   28  Female          No
# 2   Bachelors         2014  New Delhi            3   38  Female          No
# 3     Masters         2016  Bangalore            3   27    Male          No
# 4     Masters         2017       Pune            3   24    Male         Yes
# 5   Bachelors         2016  Bangalore            3   22    Male          No
# 6   Bachelors         2015  New Delhi            3   38    Male          No
# 7   Bachelors         2016  Bangalore            3   34  Female          No
# 8   Bachelors         2016       Pune            3   23    Male          No
# 9     Masters         2017  New Delhi            2   37    Male          No
# 10    Masters         2012  Bangalore            3   27    Male          No
# ...

# %%
import matplotlib.pyplot as plt

# %%
df_Employee.plot(kind= 'scatter', x ='Age',y='ExperienceInCurrentDomain')
plt.show()
